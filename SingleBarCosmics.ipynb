# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np, pandas as pd

def gaus(x, normalization, location, stdev):
    u = (x - location)/stdev
    return normalization* np.exp(-0.5*u**2)

def findindex(xvals,xval): 
    minima = 66e6
    for i,elem in enumerate(xvals):
        # Update minimum difference from xval and index of the minimum difference
        if abs(xval-elem) < minima: 
            minima = abs(xval-elem) 
            index = i
    return index

def Landau(x, location,fwhm,renormalization):
    #print(type(x))
    u=(x-location)*4/fwhm
    renormalization = 8/5*renormalization
    return renormalization * np.exp(-u/2 - np.exp(-u)/2)

# %%
with open("../LongbarTiming/trig2mV_pos232.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df232 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_fit', 'time_fit']

# %%
with open("../LongbarTiming/trig2mV_pos174.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df174 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_fit', 'time_fit']

# %%
with open("../LongbarTiming/trig2mV_pos139.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df139 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_fit', 'time_fit']

# %%
with open("../LongbarTiming/trig2mV_pos97.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df97 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_raw', 'P2P_base', 'P2P_fit', 'time_raw', 'time_base', 'time_fit']

# %%
image[-1]
# Out:
# array([ 0.   ,  0.961,  1.922,  2.883,  3.844,  4.805,  5.766,  6.727,
#         7.688,  8.649,  9.61 , 10.571, 11.532, 12.493, 13.454, 14.415,
#        15.376, 16.337, 17.298, 18.259, 19.22 , 20.181, 21.142, 22.103,
#        23.064, 24.025, 24.986, 25.947, 26.908, 27.869, 28.83 , 29.791,
#        30.752, 31.713, 32.674, 33.635, 34.596, 35.557, 36.518, 37.479,
#        38.44 , 39.401, 40.362, 41.323, 42.284, 43.245, 44.206, 45.167,
#        46.128, 47.089, 48.05 , 49.011, 49.972, 50.933, 51.894, 52.855,
#        53.816, 54.777, 55.738, 56.699, 57.66 , 58.621, 59.582, 60.543,
#        61.504, 62.465, 63.426, 64.387, 65.348, 66.309, 67.27 , 68.231,
#        69.192, 70.153, 71.114, 72.075, 73.036, 73.997, 74.958, 75.919,
#        76.88 , 77.841, 78.802, 79.763, 80.724, 81.685, 82.646, 83.607,
#        84.568, 85.529, 86.49 , 87.451, 88.412, 89.373, 90.334, 91.295,
#        92.256, 93.217, 94.178, 95.139, 96.1  ])

# %%
dfcut = df232.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")
fig,ax = plt.subplots(1,4,figsize=(20,5))
fig.suptitle("Location: Far Right", fontsize=20)

ax[0].set_title("R $V_{pp}$ vs. L $V_{pp}$")
ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(dfcut.ch3_P2P_fit,dfcut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(dfcut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(dfcut.ch4_P2P_fit+dfcut.ch3_P2P_fit,bincount,color="b", label=f"{len(dfcut.ch4_time_fit)} Events",histtype="step",range=[-50,150])

ampcenters = ampbins[:-1]/2+ampbins[1:]/2
coeff, covar = curve_fit(Landau, ampcenters, ampcounts,p0=(50,50,140))
ax[1].plot(np.linspace(-100,150,100),Landau(np.linspace(-100,150,100),*coeff),label="Landau Fit",color="r")
ax[1].legend()

TimeImage = ax[2].hist2d(dfcut.ch3_time_fit,dfcut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(dfcut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])



fig.colorbar(AmpImage[-1],ax=ax[0])

mintime = min(min(dfcut.ch4_time_fit),min(dfcut.ch3_time_fit))
maxtime = max(max(dfcut.ch4_time_fit),max(dfcut.ch3_time_fit))
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
ax[2].legend()

binresolution = 1
bincount = int(np.floor( (max(dfcut.ch4_time_fit-dfcut.ch3_time_fit)-min(dfcut.ch4_time_fit-dfcut.ch3_time_fit))/binresolution ))
gausstart,gausstop = (-30,10)
fig.colorbar(TimeImage[-1],ax=ax[2])

zoomcounts,zoombins,bars = ax[3].hist(dfcut.ch4_time_fit-dfcut.ch3_time_fit,bincount,color="b", label=f"{len(dfcut.ch4_time_fit)} Events",histtype="step")
zoomcenters = zoombins[:-1]/2+zoombins[1:]/2
coeff, covar = curve_fit(gaus, zoomcenters, zoomcounts)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlabel("R-L Time Difference (ns)")
ax[3].errorbar(zoomcenters, zoomcounts, yerr=np.sqrt(zoomcounts),color="b",linestyle="None")

ax[3].legend()
ax[3].set_xlim(gausstart,gausstop)
plt.show()
fig.tight_layout()
avg = sum(bincenters*count)/sum(count)
stdev = np.sqrt(sum((bincenters-avg)**2*count)/sum(count))


coeff, covar = curve_fit(gaus, bincenters, count)
print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# Actual Average: 4.58, Actual st.dev.: 12.57
# Fit Average:    5.09, Fit st.dev.:    3.26

# %%
dfcut = df174.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")

fig,ax = plt.subplots(1,4,figsize=(21,5))

ax[0].set_title("R $V_{pp}$ vs. L $V_{pp}$")
ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(dfcut.ch3_P2P_fit,dfcut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(dfcut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(dfcut.ch4_P2P_fit+dfcut.ch3_P2P_fit,bincount,color="b", label=f"{len(dfcut.ch4_time_fit)} Events",histtype="step",range=[-50,150])
ampcenters = ampbins[:-1]/2+ampbins[1:]/2


coeff, covar = curve_fit(gaus, ampcenters, ampcounts)
#ax[0].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit")

ax[1].plot(np.linspace(-100,150,100),gaus(np.linspace(-100,150,100),*coeff),label="Gaussian Fit",color="r")
ax[1].legend()
TimeImage = ax[2].hist2d(dfcut.ch3_time_fit,dfcut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(dfcut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])

fig.suptitle("Location: Right", fontsize=20)

fig.colorbar(TimeImage[-1])
mintime = min(min(dfcut.ch4_time_fit),min(dfcut.ch3_time_fit))
maxtime = max(max(dfcut.ch4_time_fit),max(dfcut.ch3_time_fit))
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
ax[2].legend()

binresolution = 1
bincount = int(np.floor( (max(dfcut.ch4_time_fit-dfcut.ch3_time_fit)-min(dfcut.ch4_time_fit-dfcut.ch3_time_fit))/binresolution ))
gausstart,gausstop = (-30,10)

zoomcounts,zoombins,bars = ax[3].hist(dfcut.ch4_time_fit-dfcut.ch3_time_fit,bincount,color="b", label=f"{len(dfcut.ch4_time_fit)} Events",histtype="step")
zoomcenters = zoombins[:-1]/2+zoombins[1:]/2
coeff, covar = curve_fit(gaus, zoomcenters, zoomcounts)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlabel("R-L Time Difference (ns)")
ax[3].errorbar(zoomcenters, zoomcounts, yerr=np.sqrt(zoomcounts),color="b",linestyle="None")

ax[3].legend()
ax[3].set_xlim(gausstart,gausstop)
plt.show()

avg = sum(bincenters*count)/sum(count)
stdev = np.sqrt(sum((bincenters-avg)**2*count)/sum(count))


coeff, covar = curve_fit(gaus, bincenters, count)
print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# /tmp/ipykernel_213580/3837029232.py:26: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(TimeImage[-1])
# Actual Average: -8.30, Actual st.dev.: 15.82
# Fit Average:    -10.82, Fit st.dev.:    2.89

# %%
dfcut = df139.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")

fig,ax = plt.subplots(1,4,figsize=(21,5))

ax[0].set_title("R $V_{pp}$ vs. L $V_{pp}$")
ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(dfcut.ch3_P2P_fit,dfcut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(dfcut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(dfcut.ch4_P2P_fit+dfcut.ch3_P2P_fit,bincount,color="b", label=f"{len(dfcut.ch4_time_fit)} Events",histtype="step",range=[-50,150])
ampcenters = ampbins[:-1]/2+ampbins[1:]/2


coeff, covar = curve_fit(gaus, ampcenters, ampcounts)
#ax[0].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit")

ax[1].plot(np.linspace(-100,150,100),gaus(np.linspace(-100,150,100),*coeff),label="Gaussian Fit",color="r")
ax[1].legend()
TimeImage = ax[2].hist2d(dfcut.ch3_time_fit,dfcut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(dfcut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])

fig.suptitle("Location: Center", fontsize=20)

fig.colorbar(TimeImage[-1])
mintime = min(min(dfcut.ch4_time_fit),min(dfcut.ch3_time_fit))
maxtime = max(max(dfcut.ch4_time_fit),max(dfcut.ch3_time_fit))
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
ax[2].legend()

binresolution = 1
bincount = int(np.floor( (max(dfcut.ch4_time_fit-dfcut.ch3_time_fit)-min(dfcut.ch4_time_fit-dfcut.ch3_time_fit))/binresolution ))
gausstart,gausstop = (-30,10)

zoomcounts,zoombins,bars = ax[3].hist(dfcut.ch4_time_fit-dfcut.ch3_time_fit,bincount,color="b", label=f"{len(dfcut.ch4_time_fit)} Events",histtype="step")
zoomcenters = zoombins[:-1]/2+zoombins[1:]/2
coeff, covar = curve_fit(gaus, zoomcenters, zoomcounts)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlabel("R-L Time Difference (ns)")
ax[3].errorbar(zoomcenters, zoomcounts, yerr=np.sqrt(zoomcounts),color="b",linestyle="None")

ax[3].legend()
ax[3].set_xlim(gausstart,gausstop)
plt.show()

avg = sum(bincenters*count)/sum(count)
stdev = np.sqrt(sum((bincenters-avg)**2*count)/sum(count))


coeff, covar = curve_fit(gaus, bincenters, count)
print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# /tmp/ipykernel_213580/4057107545.py:26: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(TimeImage[-1])
# Actual Average: -8.30, Actual st.dev.: 15.82
# Fit Average:    -10.82, Fit st.dev.:    2.89

# %%
dfcut = df97.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")

fig,ax = plt.subplots(1,4,figsize=(21,5))

ax[0].set_title("R $V_{pp}$ vs. L $V_{pp}$")
ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(dfcut.ch3_P2P_fit,dfcut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(dfcut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(dfcut.ch4_P2P_fit+dfcut.ch3_P2P_fit,bincount,color="b", label=f"{len(dfcut.ch4_time_fit)} Events",histtype="step",range=[-50,150])
ampcenters = ampbins[:-1]/2+ampbins[1:]/2


coeff, covar = curve_fit(gaus, ampcenters, ampcounts)
#ax[0].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit")

ax[1].plot(np.linspace(-100,150,100),gaus(np.linspace(-100,150,100),*coeff),label="Gaussian Fit",color="r")
ax[1].legend()
TimeImage = ax[2].hist2d(dfcut.ch3_time_fit,dfcut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(dfcut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])

fig.suptitle("Location: Left", fontsize=20)

fig.colorbar(TimeImage[-1])
mintime = min(min(dfcut.ch4_time_fit),min(dfcut.ch3_time_fit))
maxtime = max(max(dfcut.ch4_time_fit),max(dfcut.ch3_time_fit))
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
ax[2].legend()

binresolution = 1
bincount = int(np.floor( (max(dfcut.ch4_time_fit-dfcut.ch3_time_fit)-min(dfcut.ch4_time_fit-dfcut.ch3_time_fit))/binresolution ))
gausstart,gausstop = (-30,10)

zoomcounts,zoombins,bars = ax[3].hist(dfcut.ch4_time_fit-dfcut.ch3_time_fit,bincount,color="b", label=f"{len(dfcut.ch4_time_fit)} Events",histtype="step")
zoomcenters = zoombins[:-1]/2+zoombins[1:]/2
coeff, covar = curve_fit(gaus, zoomcenters, zoomcounts)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlabel("R-L Time Difference (ns)")
ax[3].errorbar(zoomcenters, zoomcounts, yerr=np.sqrt(zoomcounts),color="b",linestyle="None")

ax[3].legend()
ax[3].set_xlim(gausstart,gausstop)
plt.show()

avg = sum(bincenters*count)/sum(count)
stdev = np.sqrt(sum((bincenters-avg)**2*count)/sum(count))


coeff, covar = curve_fit(gaus, bincenters, count)
print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# /tmp/ipykernel_213580/3174831845.py:26: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(TimeImage[-1])
# Actual Average: -8.30, Actual st.dev.: 15.82
# Fit Average:    -10.82, Fit st.dev.:    2.89

# %%
fig,ax = plt.subplots(2,1,figsize=(15,10))
fig.suptitle("All Locations", fontsize=20)
binresolution = 1

dfcut = df232.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")

bincount = int(np.floor( (max(dfcut.ch4_time_fit-dfcut.ch3_time_fit)-min(dfcut.ch4_time_fit-dfcut.ch3_time_fit))/binresolution ))
count,binedges,bars=ax[0].hist(dfcut.ch4_time_fit-dfcut.ch3_time_fit,bincount, label=f"{len(dfcut.ch4_time_fit)} Events",color=["blue"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
ax[0].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff),label="Gaussian Fit",color="b")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="Far Right Normalized")
ax[1].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff)*renorm,label="Gaussian Fit")

dfcut = df174.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")

bincount = int(np.floor( (max(dfcut.ch4_time_fit-dfcut.ch3_time_fit)-min(dfcut.ch4_time_fit-dfcut.ch3_time_fit))/binresolution ))
count,binedges,bars=ax[0].hist(dfcut.ch4_time_fit-dfcut.ch3_time_fit,bincount, label=f"{len(dfcut.ch4_time_fit)} Events",color=["orange"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
ax[0].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff),label="Gaussian Fit",color="orange")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="Far Right Normalized")
ax[1].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff)*renorm,label="Gaussian Fit")

dfcut = df139.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")

bincount = int(np.floor( (max(dfcut.ch4_time_fit-dfcut.ch3_time_fit)-min(dfcut.ch4_time_fit-dfcut.ch3_time_fit))/binresolution ))
count,binedges,bars=ax[0].hist(dfcut.ch4_time_fit-dfcut.ch3_time_fit,bincount, label=f"{len(dfcut.ch4_time_fit)} Events",color=["green"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
ax[0].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff),label="Gaussian Fit",color="green")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="Far Right Normalized")
ax[1].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff)*renorm,label="Gaussian Fit")

dfcut = df97.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")

bincount = int(np.floor( (max(dfcut.ch4_time_fit-dfcut.ch3_time_fit)-min(dfcut.ch4_time_fit-dfcut.ch3_time_fit))/binresolution ))
count,binedges,bars=ax[0].hist(dfcut.ch4_time_fit-dfcut.ch3_time_fit,bincount, label=f"{len(dfcut.ch4_time_fit)} Events",color=["red"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
ax[0].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff),label="Gaussian Fit",color="red")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="Far Right Normalized")
ax[1].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff)*renorm,label="Gaussian Fit")


ax[0].set_xlabel("R-L Time Difference (ns)")
ax[0].legend()
ax[1].set_title("Renormalized for data set size")
ax[0].set_xlim(-30,30)
ax[1].set_xlim(-30,30)
ax[1].legend()
