# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np, pandas as pd

def gaus(x, location, stdev, normalization):
    u = (x - location)/stdev
    return normalization* np.exp(-0.5*u**2)

def findindex(xvals,xval): 
    minima = 66e6
    for i,elem in enumerate(xvals):
        # Update minimum difference from xval and index of the minimum difference
        if abs(xval-elem) < minima: 
            minima = abs(xval-elem) 
            index = i
    return index

def Landau(x, location,fwhm,renormalization):
    #print(type(x))
    u=(x-location)*4/fwhm
    renormalization = 8/5*renormalization
    return renormalization * np.exp(-u/2 - np.exp(-u)/2)

# %%
with open("./trig2mV_pos232.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df232 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_raw', 'P2P_base', 'P2P_fit', 'time_raw', 'time_base', 'time_fit']

# %%
with open("./trig2mV_pos174.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df174 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_raw', 'P2P_base', 'P2P_fit', 'time_raw', 'time_base', 'time_fit']

# %%
with open("./trig2mV_pos139.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df139 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_raw', 'P2P_base', 'P2P_fit', 'time_raw', 'time_base', 'time_fit']

# %%
with open("./trig2mV_pos97.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df97 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_raw', 'P2P_base', 'P2P_fit', 'time_raw', 'time_base', 'time_fit']

# %%
with open("./trig2mV_pos46.txt") as f:  
    stats = []
    nchannelnames=[]
    nevents = (f.read().split('\n'))
    
    nchannelnums = nevents[0].split('[')[1].split(']')[0].split(', ')
    for ch in nchannelnums:
        nchannelnames.append(f'ch{ch}')
    for i in range(len(nevents[0].split('[')[2].split(']')[0].split("'"))//2):
        stats.append(nevents[0].split('[')[2].split(']')[0].split("'")[2*i+1])

    print(f"Channels found: {nchannelnames}, stats found: {stats}")
    dout = {a+"_"+b:[] for a in nchannelnames for b in stats}
    for event in nevents[:]:
        #print(f'Event: {event}')
        nvalues = event.split()
        if len(nvalues) != len(stats)*len(nchannelnames): continue
        for i in range(len(nchannelnames)):
            for j in range(len(stats)):
                dout[f'{nchannelnames[i]}_{stats[j]}'].append(float(nvalues[len(stats)*i+j]))
    #print(dout)
df46 = pd.DataFrame(dout)
# Out:
# Channels found: ['ch1', 'ch2', 'ch3', 'ch4'], stats found: ['chisq', 'P2P_raw', 'P2P_base', 'P2P_fit', 'time_raw', 'time_base', 'time_fit']

# %%
df232cut = df232.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")
fig,ax = plt.subplots(1,4,figsize=(20,5))
fig.suptitle("Location: Far Right", fontsize=20)
binresolution = 1
bincount = int(np.floor( (max(df232cut.ch4_time_fit-df232cut.ch3_time_fit)-min(df232cut.ch4_time_fit-df232cut.ch3_time_fit))/binresolution ))

ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(df232cut.ch3_P2P_fit,df232cut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(df232cut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
fig.colorbar(AmpImage[-1],ax=ax[0])
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(df232cut.ch4_P2P_fit+df232cut.ch3_P2P_fit,bincount,color="b", label=f"{len(df232cut.ch4_time_fit)} Events",histtype="step",range=[-50,150])
ampcenters = ampbins[:-1]/2+ampbins[1:]/2
coeff, covar = curve_fit(Landau, ampcenters, ampcounts,p0=(50,50,140))
ax[1].plot(np.linspace(-100,150,100),Landau(np.linspace(-100,150,100),*coeff),label="Landau Fit",color="r")
ax[1].legend()

ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
TimeImage = ax[2].hist2d(df232cut.ch3_time_fit,df232cut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(df232cut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])
mintime = min(min(df232cut.ch4_time_fit),min(df232cut.ch3_time_fit))
maxtime = max(max(df232cut.ch4_time_fit),max(df232cut.ch3_time_fit))
fig.colorbar(TimeImage[-1],ax=ax[2])
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].legend()

ax[3].set_xlabel("L-R Time Difference (ns)")
timecounts,timebins,bars = ax[3].hist(df232cut.ch3_time_fit-df232cut.ch4_time_fit,bincount,color="b", label=f"{len(df232cut.ch4_time_fit)} Events",histtype="step")
timecenters = timebins[:-1]/2+timebins[1:]/2
coeff, covar = curve_fit(gaus, timecenters, timecounts)
gausstart,gausstop = (-10,30)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlim(-30,30)
ax[3].errorbar(timecenters, timecounts, yerr=np.sqrt(timecounts),color="b",linestyle="None")
ax[3].legend()

plt.show()
avg = sum(timecenters*timecounts)/sum(timecounts)
stdev = np.sqrt(sum((timecenters-avg)**2*timecounts)/sum(timecounts))

print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# Actual Average: 8.30, Actual st.dev.: 15.82
# Fit Average:    10.82, Fit st.dev.:    2.89

# %%
df174cut = df174.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")
fig,ax = plt.subplots(1,4,figsize=(20,5))
fig.suptitle("Location: Right", fontsize=20)
binresolution = 1
bincount = int(np.floor( (max(df174cut.ch4_time_fit-df174cut.ch3_time_fit)-min(df174cut.ch4_time_fit-df174cut.ch3_time_fit))/binresolution ))

ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(df174cut.ch3_P2P_fit,df174cut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(df174cut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
fig.colorbar(AmpImage[-1],ax=ax[0])
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(df174cut.ch4_P2P_fit+df174cut.ch3_P2P_fit,bincount,color="b", label=f"{len(df174cut.ch4_time_fit)} Events",histtype="step",range=[-50,150])
ampcenters = ampbins[:-1]/2+ampbins[1:]/2
coeff, covar = curve_fit(Landau, ampcenters, ampcounts,p0=(50,50,140))
ax[1].plot(np.linspace(-100,150,100),Landau(np.linspace(-100,150,100),*coeff),label="Landau Fit",color="r")
ax[1].legend()

ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
TimeImage = ax[2].hist2d(df174cut.ch3_time_fit,df174cut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(df174cut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])
mintime = min(min(df174cut.ch4_time_fit),min(df174cut.ch3_time_fit))
maxtime = max(max(df174cut.ch4_time_fit),max(df174cut.ch3_time_fit))
fig.colorbar(TimeImage[-1],ax=ax[2])
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].legend()

ax[3].set_xlabel("L-R Time Difference (ns)")
timecounts,timebins,bars = ax[3].hist(df174cut.ch3_time_fit-df174cut.ch4_time_fit,bincount,color="b", label=f"{len(df174cut.ch4_time_fit)} Events",histtype="step")
timecenters = timebins[:-1]/2+timebins[1:]/2
coeff, covar = curve_fit(gaus, timecenters, timecounts)
gausstart,gausstop = (-15,25)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlim(-30,30)
ax[3].errorbar(timecenters, timecounts, yerr=np.sqrt(timecounts),color="b",linestyle="None")
ax[3].legend()

plt.show()
avg = sum(timecenters*timecounts)/sum(timecounts)
stdev = np.sqrt(sum((timecenters-avg)**2*timecounts)/sum(timecounts))

print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# Actual Average: 17.97, Actual st.dev.: 34.80
# Fit Average:    4.15, Fit st.dev.:    4.56

# %%
df139cut = df139.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")
fig,ax = plt.subplots(1,4,figsize=(20,5))
fig.suptitle("Location: Center", fontsize=20)
binresolution = 1
bincount = int(np.floor( (max(df139cut.ch4_time_fit-df139cut.ch3_time_fit)-min(df139cut.ch4_time_fit-df139cut.ch3_time_fit))/binresolution ))

ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(df139cut.ch3_P2P_fit,df139cut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(df139cut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
fig.colorbar(AmpImage[-1],ax=ax[0])
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(df139cut.ch4_P2P_fit+df139cut.ch3_P2P_fit,bincount,color="b", label=f"{len(df139cut.ch4_time_fit)} Events",histtype="step",range=[-50,150])
ampcenters = ampbins[:-1]/2+ampbins[1:]/2
coeff, covar = curve_fit(Landau, ampcenters, ampcounts,p0=(50,50,140))
ax[1].plot(np.linspace(-100,150,100),Landau(np.linspace(-100,150,100),*coeff),label="Landau Fit",color="r")
ax[1].legend()

ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
TimeImage = ax[2].hist2d(df139cut.ch3_time_fit,df139cut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(df139cut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])
mintime = min(min(df139cut.ch4_time_fit),min(df139cut.ch3_time_fit))
maxtime = max(max(df139cut.ch4_time_fit),max(df139cut.ch3_time_fit))
fig.colorbar(TimeImage[-1],ax=ax[2])
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].legend()

ax[3].set_xlabel("L-R Time Difference (ns)")
timecounts,timebins,bars = ax[3].hist(df139cut.ch3_time_fit-df139cut.ch4_time_fit,bincount,color="b", label=f"{len(df139cut.ch4_time_fit)} Events",histtype="step")
timecenters = timebins[:-1]/2+timebins[1:]/2
coeff, covar = curve_fit(gaus, timecenters, timecounts)
gausstart,gausstop = (-20,20)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlim(-30,30)
ax[3].errorbar(timecenters, timecounts, yerr=np.sqrt(timecounts),color="b",linestyle="None")
ax[3].legend()

plt.show()
avg = sum(timecenters*timecounts)/sum(timecounts)
stdev = np.sqrt(sum((timecenters-avg)**2*timecounts)/sum(timecounts))

print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# Actual Average: 0.08, Actual st.dev.: 12.70
# Fit Average:    0.04, Fit st.dev.:    3.17

# %%
df97cut = df97.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")
fig,ax = plt.subplots(1,4,figsize=(20,5))
fig.suptitle("Location: Left", fontsize=20)
binresolution = 1
bincount = int(np.floor( (max(df97cut.ch4_time_fit-df97cut.ch3_time_fit)-min(df97cut.ch4_time_fit-df97cut.ch3_time_fit))/binresolution ))

ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(df97cut.ch3_P2P_fit,df97cut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(df97cut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
fig.colorbar(AmpImage[-1],ax=ax[0])
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(df97cut.ch4_P2P_fit+df97cut.ch3_P2P_fit,bincount,color="b", label=f"{len(df97cut.ch4_time_fit)} Events",histtype="step",range=[-50,150])
ampcenters = ampbins[:-1]/2+ampbins[1:]/2
coeff, covar = curve_fit(Landau, ampcenters, ampcounts,p0=(50,50,140))
ax[1].plot(np.linspace(-100,150,100),Landau(np.linspace(-100,150,100),*coeff),label="Landau Fit",color="r")
ax[1].legend()

ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
TimeImage = ax[2].hist2d(df97cut.ch3_time_fit,df97cut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(df97cut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])
mintime = min(min(df97cut.ch4_time_fit),min(df97cut.ch3_time_fit))
maxtime = max(max(df97cut.ch4_time_fit),max(df97cut.ch3_time_fit))
fig.colorbar(TimeImage[-1],ax=ax[2])
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].legend()

ax[3].set_xlabel("L-R Time Difference (ns)")
timecounts,timebins,bars = ax[3].hist(df97cut.ch3_time_fit-df97cut.ch4_time_fit,bincount,color="b", label=f"{len(df97cut.ch4_time_fit)} Events",histtype="step")
timecenters = timebins[:-1]/2+timebins[1:]/2
coeff, covar = curve_fit(gaus, timecenters, timecounts)
gausstart,gausstop = (-20,20)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlim(-30,30)
ax[3].errorbar(timecenters, timecounts, yerr=np.sqrt(timecounts),color="b",linestyle="None")
ax[3].legend()

plt.show()
avg = sum(timecenters*timecounts)/sum(timecounts)
stdev = np.sqrt(sum((timecenters-avg)**2*timecounts)/sum(timecounts))

print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# Actual Average: -4.58, Actual st.dev.: 12.57
# Fit Average:    -5.09, Fit st.dev.:    3.26

# %%
df46cut = df46.query("ch4_time_fit >= 0 & ch3_time_fit >= 0")
fig,ax = plt.subplots(1,4,figsize=(20,5))
fig.suptitle("Location: Far Left", fontsize=20)
binresolution = 1
bincount = int(np.floor( (max(df46cut.ch4_time_fit-df46cut.ch3_time_fit)-min(df46cut.ch4_time_fit-df46cut.ch3_time_fit))/binresolution ))

ax[0].set_xlabel("L $V_{pp}$ (mV)")
ax[0].set_ylabel("R $V_{pp}$ (mV)")
AmpImage = ax[0].hist2d(df46cut.ch3_P2P_fit,df46cut.ch4_P2P_fit,bins=(100,100),cmin=1,label=f"{len(df46cut.ch4_time_fit)} Events",range=[[0, 100], [0, 100]])
ax[0].plot(np.linspace(0,100,2),np.linspace(0,100,2),color="red",label="L=R")
fig.colorbar(AmpImage[-1],ax=ax[0])
ax[0].legend()

ax[1].set_xlabel("R+L Total Amplitude (mV)")
ampcounts,ampbins,ampbars = ax[1].hist(df46cut.ch4_P2P_fit+df46cut.ch3_P2P_fit,bincount,color="b", label=f"{len(df46cut.ch4_time_fit)} Events",histtype="step",range=[-50,150])
ampcenters = ampbins[:-1]/2+ampbins[1:]/2
coeff, covar = curve_fit(Landau, ampcenters, ampcounts,p0=(30,30,140))
ax[1].plot(np.linspace(-100,150,100),Landau(np.linspace(-100,150,100),*coeff),label="Landau Fit",color="r")
ax[1].legend()

ax[2].set_xlabel("SiPM_L Signal Time")
ax[2].set_ylabel("SiPM_R Signal Time")
TimeImage = ax[2].hist2d(df46cut.ch3_time_fit,df46cut.ch4_time_fit,bins=(100,100),cmin=1,label=f"{len(df46cut.ch4_time_fit)} Events",range=[[40, 120], [40, 120]])
mintime = min(min(df46cut.ch4_time_fit),min(df46cut.ch3_time_fit))
maxtime = max(max(df46cut.ch4_time_fit),max(df46cut.ch3_time_fit))
fig.colorbar(TimeImage[-1],ax=ax[2])
ax[2].plot(np.linspace(mintime,maxtime,2),np.linspace(mintime,maxtime,2),color="red",label="L=R")
ax[2].legend()

ax[3].set_xlabel("L-R Time Difference (ns)")
timecounts,timebins,bars = ax[3].hist(df46cut.ch3_time_fit-df46cut.ch4_time_fit,bincount,color="b", label=f"{len(df46cut.ch4_time_fit)} Events",histtype="step")
timecenters = timebins[:-1]/2+timebins[1:]/2
coeff, covar = curve_fit(gaus, timecenters, timecounts)
gausstart,gausstop = (-30,10)
ax[3].plot(np.linspace(gausstart,gausstop,50),gaus(np.linspace(gausstart,gausstop,50),*coeff),label="Gaussian Fit",color="r")
ax[3].set_xlim(-30,30)
ax[3].errorbar(timecenters, timecounts, yerr=np.sqrt(timecounts),color="b",linestyle="None")
ax[3].legend()

plt.show()
avg = sum(timecenters*timecounts)/sum(timecounts)
stdev = np.sqrt(sum((timecenters-avg)**2*timecounts)/sum(timecounts))

print(f"Actual Average: {avg:.2f}, Actual st.dev.: {stdev:.2f}")
print(f"Fit Average:    {coeff[1]:.2f}, Fit st.dev.:    {coeff[2]:.2f}")
# Out:
# Actual Average: -16.62, Actual st.dev.: 31.02
# Fit Average:    -9.94, Fit st.dev.:    4.36

# %%
fig,ax = plt.subplots(2,1,figsize=(15,10))
fig.suptitle("All Locations", fontsize=20)
binresolution = 1


bincount = int(np.floor( (max(df232cut.eval("ch3_time_fit-ch4_time_fit"))-min(df232cut.eval("ch3_time_fit-ch4_time_fit")))/binresolution ))
count,binedges,bars=ax[0].hist(df232cut.eval("ch3_time_fit-ch4_time_fit"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events",color=["blue"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
print(coeff)
ax[0].plot(np.linspace(-10,30,50),gaus(np.linspace(-10,30,50),*coeff),label="Gaussian Fit",color="b")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="Far Right Normalized")
ax[1].plot(np.linspace(-10,30,50),gaus(np.linspace(-10,30,50),*coeff)*renorm,label="Gaussian Fit")



bincount = int(np.floor( (max(df174cut.ch4_time_fit-df174cut.ch3_time_fit)-min(df174cut.ch4_time_fit-df174cut.ch3_time_fit))/binresolution ))
count,binedges,bars=ax[0].hist(df174cut.ch3_time_fit-df174cut.ch4_time_fit,bincount, label=f"{len(df174cut.ch4_time_fit)} Events",color=["orange"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
print(coeff)
ax[0].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff),label="Gaussian Fit",color="orange")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="Right Normalized")
ax[1].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff)*renorm,label="Gaussian Fit")



bincount = int(np.floor( (max(df139cut.ch4_time_fit-df139cut.ch3_time_fit)-min(df139cut.ch4_time_fit-df139cut.ch3_time_fit))/binresolution ))
count,binedges,bars=ax[0].hist(df139cut.ch3_time_fit-df139cut.ch4_time_fit,bincount, label=f"{len(df139cut.ch4_time_fit)} Events",color=["green"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
print(coeff)
ax[0].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff),label="Gaussian Fit",color="green")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="Center Normalized")
ax[1].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff)*renorm,label="Gaussian Fit")



bincount = int(np.floor( (max(df97cut.ch4_time_fit-df97cut.ch3_time_fit)-min(df97cut.ch4_time_fit-df97cut.ch3_time_fit))/binresolution ))
count,binedges,bars=ax[0].hist(df97cut.ch3_time_fit-df97cut.ch4_time_fit,bincount, label=f"{len(df97cut.ch4_time_fit)} Events",color=["red"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
print(coeff)
ax[0].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff),label="Gaussian Fit",color="red")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="left Normalized")
ax[1].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff)*renorm,label="Gaussian Fit")

bincount = int(np.floor( (max(df46cut.ch4_time_fit-df46cut.ch3_time_fit)-min(df46cut.ch4_time_fit-df46cut.ch3_time_fit))/binresolution ))
count,binedges,bars=ax[0].hist(df46cut.ch3_time_fit-df46cut.ch4_time_fit,bincount, label=f"{len(df46cut.ch4_time_fit)} Events",color=["purple"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(gaus, bincenters, count)
print(coeff)
ax[0].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff),label="Gaussian Fit",color="purple")
renorm = 137/max(count)
ax[1].bar(bincenters,count*renorm,label="Far left Normalized")
ax[1].plot(np.linspace(-30,10,50),gaus(np.linspace(-30,10,50),*coeff)*renorm,label="Gaussian Fit")


ax[0].set_xlabel("L-R Time Difference (ns)")
ax[0].legend()
ax[1].set_title("Renormalized for data set size")
ax[0].set_xlim(-30,30)
ax[1].set_xlim(-30,30)
ax[1].legend()
# Out:
# [785.387668    10.82462154   2.88512893]
# [123.40226984   4.15287421   4.55719541]
# [3.91407353e+02 3.78235444e-02 3.17012804e+00]
# [654.38626579  -5.09391334   3.25942343]
# [140.62914277  -9.94047835   4.35731598]

# %%
x = [10.82462155, 4.15287421, 3.78234934e-02, -5.09391334, -9.94047835]
err = [2.88512896, 4.55719541, 3.17012804, 3.25942343, 4.35731598]
y = [232-14,174-14,139-14,97-14,46-14]

plt.errorbar(x,y,xerr = err,fmt = 'o', color = "blue", ecolor = "blue", label = "Raw")
p = np.polyfit(x,y,1)
plt.plot(x,np.array(x)*p[0]+p[1],label = "Fit")
plt.xlabel("L-R Time (ns)")
plt.ylabel("Position (cm)")
plt.annotate(str(f"Slope (cm/ns): {p[0]:.2f}"), xy = (x[-1] + 10, y[-2]))
plt.legend()
plt.show()

# %%
y = [10.82462155, 4.15287421, 3.78234934e-02, -5.09391334, -9.94047835]
err = [2.88512896, 4.55719541, 3.17012804, 3.25942343, 4.35731598]
x = [232-14,174-14,139-14,97-14,46-14]

plt.errorbar(x,y,yerr = err,fmt = 'o', color = "blue", ecolor = "blue", label = "Raw")
p = np.polyfit(x,y,1)
plt.plot(x,np.array(x)*p[0]+p[1],label = "Fit")
plt.ylabel("L-R Time (ns)")
plt.xlabel("Position (cm)")
plt.annotate(str(f"Slope (ns/cm): {p[0]:.2f}"), xy = (x[-2] + 10, y[-2]))
plt.legend()
plt.show()

# %%
#calculate residuals for each of the five locations and in total
binresolution = 1


bincount = int(np.floor( ( max(df232cut.eval("ch3_time_fit-ch4_time_fit")) - min(df232cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count232,binedges232,bars232=plt.hist(df232cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
bincount = int(np.floor( ( max(df174cut.eval("ch3_time_fit-ch4_time_fit")) - min(df174cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count174,binedges174,bars174=plt.hist(df174cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
bincount = int(np.floor( ( max(df139cut.eval("ch3_time_fit-ch4_time_fit")) - min(df139cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count139,binedges139,bars139=plt.hist(df139cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
bincount = int(np.floor( ( max(df97cut.eval("ch3_time_fit-ch4_time_fit")) - min(df97cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count97,binedges97,bars97=ax[0].hist(df97cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
bincount = int(np.floor( ( max(df46cut.eval("ch3_time_fit-ch4_time_fit")) - min(df46cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count46,binedges46,bars46=plt.hist(df46cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
print(max(count232),max(count174),max(count139),max(count97),max(count46))
plt.clf()
fig,ax = plt.subplots(2,1,figsize=(15,10))

fig.suptitle("All Locations", fontsize=20)

print(max(count97))

bincount = int(np.floor( ( max(df232cut.eval("ch3_time_fit-ch4_time_fit")) - min(df232cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df232cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events",color=["blue"],weights=[137/max(count232)]*len(df232cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count232)), color = "blue",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,250,50))
ax[0].plot(np.linspace(0,300,50),gaus(np.linspace(0,300,50),*coeff),label="Gaussian Fit",color="b")

bincount = int(np.floor( ( max(df174cut.eval("ch3_time_fit-ch4_time_fit")) - min(df174cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df174cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df174cut.ch4_time_fit)} Events",color=["orange"],weights=[137/max(count174)]*len(df174cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count174)), color = "orange",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,200,50))
ax[0].plot(np.linspace(0,300,50),gaus(np.linspace(0,300,50),*coeff),label="Gaussian Fit",color="orange")

bincount = int(np.floor( ( max(df139cut.eval("ch3_time_fit-ch4_time_fit")) - min(df139cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df139cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df139cut.ch4_time_fit)} Events",color=["green"],weights=[137/max(count139)]*len(df139cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count139)), color = "green",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,125,50))
ax[0].plot(np.linspace(0,300,50),gaus(np.linspace(0,300,50),*coeff),label="Gaussian Fit",color="green")

bincount = int(np.floor( ( max(df97cut.eval("ch3_time_fit-ch4_time_fit")) - min(df97cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df97cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df97cut.ch4_time_fit)} Events",color=["red"],weights=[137/max(count97)]*len(df97cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count97)), color = "red",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,75,50))
ax[0].plot(np.linspace(0,300,50),gaus(np.linspace(0,300,50),*coeff),label="Gaussian Fit",color="red")

bincount = int(np.floor( ( max(df46cut.eval("ch3_time_fit-ch4_time_fit")) - min(df46cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df46cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df46cut.ch4_time_fit)} Events",color=["purple"],weights=[137/max(count46)]*len(df46cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count46)), color = "purple",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,75,50))
ax[0].plot(np.linspace(-50,300,50),gaus(np.linspace(-50,300,50),*coeff),label="Gaussian Fit",color="purple")

#residuals
rescount,resbins,resbars = ax[1].hist(df232cut.eval(f"((ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]})-(232-14)"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events",color=["blue"],weights=[137/max(counto)]*len(df232cut.ch3_time_fit),histtype="step")
rescenters = resbins[1:]/2+resbins[:-1]/2
coeff, covar = curve_fit(gaus, rescenters, rescount,p0=(135,0,50))
ax[1].plot(np.linspace(-100,100,50),gaus(np.linspace(-100,100,50),*coeff)*renorm,label="Gaussian Fit",color="b")
ax[1].errorbar(rescenters,rescount,yerr = np.sqrt(count)*np.sqrt(137/max(count232)), color = "blue",linestyle="")

ax[0].set_xlabel("L-R Time Difference (ns)")
ax[0].legend()
ax[1].set_title("Renormalized for data set size")
ax[0].set_xlim(-50,300)
ax[1].set_xlim(-100,100)
ax[1].legend()
plt.show()
# Out:
# 8.11e+02 137.0 397.0 700.0 150.0
# 700.0

# %%
[1,2,3]+[4,5,6]
# Out:
# [6139, 6139, 6139]
# [2059, 2059, 2059]
# [3310, 3310, 3310]
# [5705, 5705, 5705]
# [2056, 2056, 2056]
# [6139,
#  6139,
#  6139,
#  2059,
#  2059,
#  2059,
#  3310,
#  3310,
#  3310,
#  5705,
#  5705,
#  5705,
#  2056,
#  2056,
#  2056]

# %%
dataframes=[df232cut,df174cut,df139cut,df97cut,df46cut]
histdatas= [(-666,-666,-666)]*5
locations=[232-14,174-14,139-14,97-14,46-14]
colors=["blue","orange","green","red","purple"]
allresiduals=[]
binresolution = 1
for i in range(len(dataframes)):
    bincount = int(np.floor( ( max(dataframes[i].eval("ch3_time_fit-ch4_time_fit")) - min(dataframes[i].eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
    histdatas[i]=plt.hist(dataframes[i].eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(dataframes[i].ch4_time_fit)} Events")
    print("bin resolution",binedges[1]-binedges[0])
    print(max(dataframes[i].eval("ch3_time_fit-ch4_time_fit")) - min(dataframes[i].eval("ch3_time_fit-ch4_time_fit")),bincount)
    plt.clf()

fig,ax = plt.subplots(3,1,figsize=(20,10))
fig.suptitle("All Locations", fontsize=20)


for i in range(len(dataframes)):
    bincount = int(np.floor( ( max(dataframes[i].eval(f"ch3_time_fit-ch4_time_fit*{p[0]}+{p[1]}")) - min(dataframes[i].eval(f"ch3_time_fit-ch4_time_fit*{p[0]}+{p[1]}")) )/binresolution ))
    print("bin resolution",binedges[1]-binedges[0])
    print(max(dataframes[i].eval("ch3_time_fit-ch4_time_fit")) - min(dataframes[i].eval("ch3_time_fit-ch4_time_fit")),bincount)
    
    count,binedges,bars=ax[0].hist(dataframes[i].eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(dataframes[i].ch4_time_fit)} Events",color=colors[i],weights=[137/max(histdatas[i][0])]*len(dataframes[i].ch3_time_fit),histtype="step")
    bincenters = binedges[1:]/2+binedges[:-1]/2
    ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(histdatas[i][0])), color = colors[i],linestyle="")
    coeff, covar = curve_fit(gaus, bincenters, count,p0=(125,50,137))
    ax[0].plot(np.linspace(-50,300,50),gaus(np.linspace(-50,300,50),*coeff),label="Gaussian Fit",color=colors[i])
    
    allresiduals += dataframes[i].eval(f"((ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]})-({locations[i]})").tolist()
    
    rescount,resbins,resbars = ax[1].hist(dataframes[i].eval(f"((ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]})-({locations[i]})"),bincount, label=f"{len(dataframes[i].ch4_time_fit)} Events",color=colors[i],weights=[137/max(histdatas[i][0])]*len(dataframes[i].ch3_time_fit),histtype="step")
    rescenters = resbins[1:]/2+resbins[:-1]/2
    coeff, covar = curve_fit(gaus, rescenters, rescount,p0=(0,50,135))
    ax[1].plot(np.linspace(-100,100,50),gaus(np.linspace(-100,100,50),*coeff)*renorm,label="Gaussian Fit",color=colors[i])
    ax[1].errorbar(rescenters,rescount,yerr = np.sqrt(count)*np.sqrt(137/max(histdatas[i][0])), color = colors[i],linestyle="")

bincount = int(np.floor( ( max(allresiduals) - min(allresiduals) )/binresolution ))
print(len(allresiduals))
rescount,resbins,resbars = ax[2].hist(allresiduals,bincount, label=f"{len(dataframes[i].ch4_time_fit)} Events",color=["blue"],histtype="step")
print("bin resolution",resbins[1]-resbins[0])
rescenters = resbins[1:]/2+resbins[:-1]/2
coeff, covar = curve_fit(gaus, rescenters, rescount,p0=(0,50,135))
ax[2].plot(np.linspace(-100,100,50),gaus(np.linspace(-100,100,50),*coeff),label="Gaussian Fit",color=colors[i])
ax[2].errorbar(rescenters,rescount,yerr = np.sqrt(rescount), color = colors[i],linestyle="")

ax[0].set_xlim(-50,300)
ax[1].set_xlim(-10,10)
ax[2].set_xlim(-100,100)
# Out:
# bin resolution 1.5937602747505935e+00
# 217.5 217
# bin resolution 1.5937602747505935
# 197.3 197
# bin resolution 1.5937602747505935
# 275.6 275
# bin resolution 1.5937602747505935
# 383.3 383
# bin resolution 1.5937602747505935
# 207.4 207
# bin resolution 1.5937602747505935
# 217.5 930
# bin resolution 2.066752152725485e+00
# 197.3 1506
# bin resolution 1.1577484262229518e+00
# 275.6 1608
# bin resolution 1.5146254668061374e+00
# 383.3 1298
# bin resolution 2.6096136341672036e+00
# 207.4 1150
# 19269
# bin resolution 1.0000268880628482e+00
# (-100.0, 100.0)

# %%
max(allresiduals) - min(allresiduals)
# Out:
# 4122.110832595118

# %%
import test

# %%
test.test1()
# Out:
# hi!

# %%
#calculate residuals for each of the five locations and in total


bincount = int(np.floor( ( max(df232cut.eval("ch3_time_fit-ch4_time_fit")) - min(df232cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count232,binedges232,bars232=plt.hist(df232cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
bincount = int(np.floor( ( max(df174cut.eval("ch3_time_fit-ch4_time_fit")) - min(df174cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count174,binedges174,bars174=plt.hist(df174cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
bincount = int(np.floor( ( max(df139cut.eval("ch3_time_fit-ch4_time_fit")) - min(df139cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count139,binedges139,bars139=plt.hist(df139cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
bincount = int(np.floor( ( max(df97cut.eval("ch3_time_fit-ch4_time_fit")) - min(df97cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count97,binedges97,bars97=ax[0].hist(df97cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
bincount = int(np.floor( ( max(df46cut.eval("ch3_time_fit-ch4_time_fit")) - min(df46cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count46,binedges46,bars46=plt.hist(df46cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events")
print(max(count232),max(count174),max(count139),max(count97),max(count46))
plt.clf()
fig,ax = plt.subplots(2,1,figsize=(15,10))

fig.suptitle("All Locations", fontsize=20)

print(max(count97))

bincount = int(np.floor( ( max(df232cut.eval("ch3_time_fit-ch4_time_fit")) - min(df232cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df232cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events",color=["blue"],weights=[137/max(count232)]*len(df232cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count232)), color = "blue",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,250,50))
ax[0].plot(np.linspace(0,300,50),gaus(np.linspace(0,300,50),*coeff),label="Gaussian Fit",color="b")

bincount = int(np.floor( ( max(df174cut.eval("ch3_time_fit-ch4_time_fit")) - min(df174cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df174cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df174cut.ch4_time_fit)} Events",color=["orange"],weights=[137/max(count174)]*len(df174cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count174)), color = "orange",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,200,50))
ax[0].plot(np.linspace(0,300,50),gaus(np.linspace(0,300,50),*coeff),label="Gaussian Fit",color="orange")

bincount = int(np.floor( ( max(df139cut.eval("ch3_time_fit-ch4_time_fit")) - min(df139cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df139cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df139cut.ch4_time_fit)} Events",color=["green"],weights=[137/max(count139)]*len(df139cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count139)), color = "green",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,125,50))
ax[0].plot(np.linspace(0,300,50),gaus(np.linspace(0,300,50),*coeff),label="Gaussian Fit",color="green")

bincount = int(np.floor( ( max(df97cut.eval("ch3_time_fit-ch4_time_fit")) - min(df97cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df97cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df97cut.ch4_time_fit)} Events",color=["red"],weights=[137/max(count97)]*len(df97cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count97)), color = "red",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,75,50))
ax[0].plot(np.linspace(0,300,50),gaus(np.linspace(0,300,50),*coeff),label="Gaussian Fit",color="red")

bincount = int(np.floor( ( max(df46cut.eval("ch3_time_fit-ch4_time_fit")) - min(df46cut.eval("ch3_time_fit-ch4_time_fit")) )/binresolution ))
count,binedges,bars=ax[0].hist(df46cut.eval(f"(ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]}"),bincount, label=f"{len(df46cut.ch4_time_fit)} Events",color=["purple"],weights=[137/max(count46)]*len(df46cut.ch3_time_fit),histtype="step")
bincenters = binedges[1:]/2+binedges[:-1]/2
ax[0].errorbar(bincenters,count,yerr = np.sqrt(count)*np.sqrt(137/max(count46)), color = "purple",linestyle="")
coeff, covar = curve_fit(gaus, bincenters, count,p0=(135,75,50))
ax[0].plot(np.linspace(-50,300,50),gaus(np.linspace(-50,300,50),*coeff),label="Gaussian Fit",color="purple")

#residuals
rescount,resbins,resbars = ax[1].hist(df232cut.eval(f"((ch3_time_fit-ch4_time_fit)*{p[0]}+{p[1]})-(232-14)"),bincount, label=f"{len(df232cut.ch4_time_fit)} Events",color=["blue"],weights=[137/max(counto)]*len(df232cut.ch3_time_fit),histtype="step")
rescenters = resbins[1:]/2+resbins[:-1]/2
coeff, covar = curve_fit(gaus, rescenters, rescount,p0=(135,0,50))
ax[1].plot(np.linspace(-100,100,50),gaus(np.linspace(-100,100,50),*coeff)*renorm,label="Gaussian Fit",color="b")
ax[1].errorbar(rescenters,rescount,yerr = np.sqrt(count)*np.sqrt(137/max(count232)), color = "blue",linestyle="")

ax[0].set_xlabel("L-R Time Difference (ns)")
ax[0].legend()
ax[1].set_title("Renormalized for data set size")
ax[0].set_xlim(-50,300)
ax[1].set_xlim(-100,100)
ax[1].legend()
plt.show()
# Out:
# 8.11e+02 137.0 397.0 700.0 150.0
# 700.0

# %%
np.sqrt(137/max(counto))
# Out:
# 4.1100760371100364e-01

# %%
fig,ax = plt.subplots(5,1,figsize=(15,20))
fig.suptitle("All Locations", fontsize=20)
binresolution = 1


bincount = int(np.floor( (max(df232cut.ch4_P2P_fit)-min(df232cut.ch4_P2P_fit))/binresolution ))
count,binedges,bars=ax[0].hist(df232cut.ch4_P2P_fit,bincount, label=f"{len(df232cut.ch4_P2P_fit)} Events",color=["blue"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(Landau, bincenters, count)
ax[0].plot(np.linspace(0,100,100),Landau(np.linspace(0,100,100),*coeff), label=f"Landau Fit",color="b")
coeffG, covarG = curve_fit(gaus, bincenters, count)
ax[0].plot(np.linspace(0,100,100),gaus(np.linspace(0,100,100),*coeffG), label=f"Landau Fit",color="g")
print(f"ch4 Landau renorm {coeff[2]:.2f}, Landau location {coeff[0]:.2f}, hwhm {coeff[1]/2:.2f}, ch4 gaus renorm {coeffG[0]:.2f}, location {coeffG[1]:.2f}, stdev {coeffG[2]:.2f}")

bincount = int(np.floor( (max(df174cut.ch3_P2P_fit)-min(df174cut.ch3_P2P_fit))/binresolution ))
count,binedges,bars=ax[1].hist(df174cut.ch3_P2P_fit,bincount, label=f"{len(df174cut.ch3_P2P_fit)} Events",color=["green"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(Landau, bincenters, count,p0=(10,5,80))
ax[1].plot(np.linspace(0,100,100),Landau(np.linspace(0,100,100),*coeff), label=f"Landau Fit",color="g")
print("ch4 location,fwhm,renormalization: ", coeff)

bincount = int(np.floor( (max(df139cut.ch4_P2P_fit)-min(df139cut.ch4_P2P_fit))/binresolution ))
count,binedges,bars=ax[2].hist(df139cut.ch4_P2P_fit,bincount, label=f"{len(df139cut.ch4_P2P_fit)} Events",color=["yellow"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(Landau, bincenters, count)
ax[2].plot(np.linspace(0,100,100),Landau(np.linspace(0,100,100),*coeff), label=f"Landau Fit",color="y")
print("ch4 location,fwhm,renormalization: ", coeff)

bincount = int(np.floor( (max(df97cut.ch4_P2P_fit)-min(df97cut.ch4_P2P_fit))/binresolution ))
count,binedges,bars=ax[3].hist(df97cut.ch4_P2P_fit,bincount, label=f"{len(df97cut.ch4_P2P_fit)} Events",color=["red"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(Landau, bincenters, count)
ax[3].plot(np.linspace(0,100,100),Landau(np.linspace(0,100,100),*coeff), label=f"Landau Fit",color="r")
print("ch4 location,fwhm,renormalization: ", coeff)

bincount = int(np.floor( (max(df46cut.ch4_P2P_fit)-min(df46cut.ch4_P2P_fit))/binresolution ))
count,binedges,bars=ax[4].hist(df46cut.ch4_P2P_fit,bincount, label=f"{len(df46cut.ch4_P2P_fit)} Events",color=["orange"])
bincenters = binedges[1:]/2+binedges[:-1]/2
coeff, covar = curve_fit(Landau, bincenters, count)
ax[4].plot(np.linspace(0,100,100),Landau(np.linspace(0,100,100),*coeff), label=f"Landau Fit",color="r")
print("ch4 location,fwhm,renormalization: ", coeff)

#ax[0].set_xlim(0,100)
# Out:
# ch4 Landau renorm 180.98, Landau location 29.26, hwhm 16.98, ch4 gaus renorm 170.79, location 33.83, stdev 13.55
# ch4 location,fwhm,renormalization:  [14.53836451 23.52266377 88.71226152]
# ch4 location,fwhm,renormalization:  [ 13.53312088  21.75838613 151.54480067]
# ch4 location,fwhm,renormalization:  [ 12.21583705  20.23968784 283.66593281]
# ch4 location,fwhm,renormalization:  [  8.5896815   16.5106658  125.52370723]
